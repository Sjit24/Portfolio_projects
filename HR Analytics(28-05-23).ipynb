# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('employees.csv')

# %%
df
# Out:
#        satisfactoryLevel  lastEvaluation  numberOfProjects  avgMonthlyHours  \
# 0                   0.38            0.53                 2              157
# 1                   0.80            0.86                 5              262
# 2                   0.11            0.88                 7              272
# 3                   0.37            0.52                 2              159
# 4                   0.41            0.50                 2              153
# ...                  ...             ...               ...              ...
# 14994               0.11            0.85                 7              275
# 14995               0.99            0.83                 4              274
# 14996               0.72            0.72                 4              175
# 14997               0.24            0.91                 5              177
# 14998               0.77            0.83                 6              271
#
# ...

# %%
# Exploring the data
df.head()
# Out:
#    satisfactoryLevel  lastEvaluation  numberOfProjects  avgMonthlyHours  \
# 0               0.38            0.53                 2              157
# 1               0.80            0.86                 5              262
# 2               0.11            0.88                 7              272
# 3               0.37            0.52                 2              159
# 4               0.41            0.50                 2              153
#
#    timeSpent.company  workAccident  left  promotionInLast5years   dept  salary
# 0                  3             0     1                      0  sales     low
# 1                  6             0     1                      0  sales  medium
# 2                  4             0     1                      0  sales  medium
# 3                  3             0     1                      0  sales     low
# 4                  3             0     1                      0  sales     low

# %%
df.tail()
# Out:
#        satisfactoryLevel  lastEvaluation  numberOfProjects  avgMonthlyHours  \
# 14994               0.11            0.85                 7              275
# 14995               0.99            0.83                 4              274
# 14996               0.72            0.72                 4              175
# 14997               0.24            0.91                 5              177
# 14998               0.77            0.83                 6              271
#
#        timeSpent.company  workAccident  left  promotionInLast5years  \
# 14994                  4             0     1                      0
# 14995                  2             0     0                      0
# 14996                  4             0     0                      0
# 14997                  5             0     0                      0
# 14998                  3             0     0                      0
#
#             dept  salary
# 14994    support  medium
# 14995      sales     low
# ...

# %%
# If I want to know the number of rows and columns present in the dataset
df.shape
# Out:
# (14999, 10)

# %%
# If I want to have more information about the columns
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14999 entries, 0 to 14998
# Data columns (total 10 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   satisfactoryLevel      14999 non-null  float64
#  1   lastEvaluation         14999 non-null  float64
#  2   numberOfProjects       14999 non-null  int64
#  3   avgMonthlyHours        14999 non-null  int64
#  4   timeSpent.company      14999 non-null  int64
#  5   workAccident           14999 non-null  int64
#  6   left                   14999 non-null  int64
#  7   promotionInLast5years  14999 non-null  int64
#  8   dept                   14999 non-null  object
#  9   salary                 14999 non-null  object
# dtypes: float64(2), int64(6), object(2)
# memory usage: 1.1+ MB

# %%
# For getting a detailed description/statistical analysis
df.describe()
# Out:
#        satisfactoryLevel  lastEvaluation  numberOfProjects  avgMonthlyHours  \
# count       14999.000000    14999.000000      14999.000000     14999.000000
# mean            0.612834        0.716102          3.803054       201.050337
# std             0.248631        0.171169          1.232592        49.943099
# min             0.090000        0.360000          2.000000        96.000000
# 25%             0.440000        0.560000          3.000000       156.000000
# 50%             0.640000        0.720000          4.000000       200.000000
# 75%             0.820000        0.870000          5.000000       245.000000
# max             1.000000        1.000000          7.000000       310.000000
#
#        timeSpent.company  workAccident          left  promotionInLast5years
# count       14999.000000  14999.000000  14999.000000           14999.000000
# mean            3.498233      0.144610      0.238083               0.021268
# ...

# %%
# Data Preprocessing --
# Null values
# Duplicate records
# Correlation

# %%
# For checking if null values are present in the data
df.isnull().sum()
# Out:
# satisfactoryLevel        0
# lastEvaluation           0
# numberOfProjects         0
# avgMonthlyHours          0
# timeSpent.company        0
# workAccident             0
# left                     0
# promotionInLast5years    0
# dept                     0
# salary                   0
# dtype: int64

# %%
# If null values were present
# df.dropna() --> For removing the null values
# Replace the null values --> fillna()
#     Data type of the column is object --> replace the null values with mode of the column
#     Data type of the column is int/float --> replace the null values with mean of the column

# %%
# Checking for duplicate records/rows
# If all the values of a particular row is being repeated in some other row --> duplicate row
df.duplicated().sum()
# Out:
# 3008

# %%
# For removing the duplicate rows -->
df = df.drop_duplicates()

# %%
df.shape
# Out:
# (11991, 10)

# %%
# Correlation --> How two columns are related to each other
# Positive --> When the columns are directly proportional to each other
# Negative --> When the columns are inversely proportional to each other
# Zero     --> When the columns are not related

# -1 to 1
df.corr()
# Out:
#                        satisfactoryLevel  lastEvaluation  numberOfProjects  \
# satisfactoryLevel               1.000000        0.095186         -0.133246
# lastEvaluation                  0.095186        1.000000          0.270256
# numberOfProjects               -0.133246        0.270256          1.000000
# avgMonthlyHours                -0.006252        0.264678          0.331516
# timeSpent.company              -0.152915        0.096829          0.188837
# workAccident                    0.039940       -0.005695         -0.005612
# left                           -0.350558        0.013520          0.030928
# promotionInLast5years           0.019789       -0.007206         -0.000544
#
#                        avgMonthlyHours  timeSpent.company  workAccident  \
# satisfactoryLevel            -0.006252          -0.152915      0.039940
# lastEvaluation                0.264678           0.096829     -0.005695
# numberOfProjects              0.331516           0.188837     -0.005612
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.heatmap(df.corr(), annot = True, cmap = 'Greens')
# Out:
# <AxesSubplot:>

# %%
l = ['abc', 12, 5.5]

# %%
for i in range(len(l)):
    print(i)
# Out:
# 0
# 1
# 2

# %%
# enumerate --> It takes two traversing variables
for i,j in enumerate(l):
    print(i,j)
    
# i --> index value
# j --> data present at that index value
# Out:
# 0 abc
# 1 12
# 2 5.5

# %%
df
# Out:
#        satisfactoryLevel  lastEvaluation  numberOfProjects  avgMonthlyHours  \
# 0                   0.38            0.53                 2              157
# 1                   0.80            0.86                 5              262
# 2                   0.11            0.88                 7              272
# 3                   0.37            0.52                 2              159
# 4                   0.41            0.50                 2              153
# ...                  ...             ...               ...              ...
# 14992               0.30            0.88                 5              245
# 14995               0.99            0.83                 4              274
# 14996               0.72            0.72                 4              175
# 14997               0.24            0.91                 5              177
# 14998               0.77            0.83                 6              271
#
# ...

# %%
df.columns
# Out:
# Index(['satisfactoryLevel', 'lastEvaluation', 'numberOfProjects',
#        'avgMonthlyHours', 'timeSpent.company', 'workAccident', 'left',
#        'promotionInLast5years', 'dept', 'salary'],
#       dtype='object')

# %%
a = ['dept', 'numberOfProjects', 'timeSpent.company', 'workAccident', 'promotionInLast5years', 'salary']

# %%
a
# Out:
# ['dept',
#  'numberOfProjects',
#  'timeSpent.company',
#  'workAccident',
#  'promotionInLast5years',
#  'salary']

# %%
for i,j in enumerate(a):
    print(i,j)
# Out:
# 0 dept
# 1 numberOfProjects
# 2 timeSpent.company
# 3 workAccident
# 4 promotionInLast5years
# 5 salary

# %%
fig = plt.subplots(3,2, figsize = (30,25))

for i,j in enumerate(a):
    plt.subplot(3,2, i+1)  # i = 0, plt.subplot(3,2,1), (3,2,2), ...., (3,2,6)
    sns.countplot(x = j, data = df, hue = 'left')
plt.show()

# %%
# Conclusions
# 1. The most no. of people who are churning out belongs to sales department, but the highest attrition
#    rate belongs to technical and support departments.
# 2. When the number of projects is minimum, the employee might feel that he is being underutilized
#    When the number of projects is maximum, the employee might feel that he is being overburdened.
#    3-4 number of projects are the most suitable ones.
# 3. The time period of 3-5 years is the most crucial period for the company.
# 4. Work accident does not play a major role in the emplyees' decision-making.
# 5. Promotion plays a very significant role in the employees' decision.
# 6. Most of the employees who are leaving are getting low/medium salary.

# %% [markdown]
# # New Section

# %% [markdown]
# # New Section
